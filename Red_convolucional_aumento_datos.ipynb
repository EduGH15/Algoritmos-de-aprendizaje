# %% [markdown]
# <a href="https://colab.research.google.com/github/EduGH15/Algoritmos-de-aprendizaje/blob/main/Red_convolucional_aumento_datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
import numpy as np
from tensorflow.keras.utils import to_categorical

#Cargar los datos de MNIST
#Aqui lo hago de otra manera porque es mas simple para poder usar el modulo de aumento de datos
#de Keras de esta manera
(X_entrenamiento, Y_entrenamiento), (X_pruebas, Y_pruebas) = mnist.load_data()

# %%
#Colocar los datos en la forma correcta que ya hemos visto (1, 28, 28, 1)
X_entrenamiento = X_entrenamiento.reshape(X_entrenamiento.shape[0], 28, 28, 1)
X_pruebas = X_pruebas.reshape(X_pruebas.shape[0], 28, 28, 1)

#Hacer 'one-hot encoding' de los resultados (e.g. en lugar de tener como resultado una sola neurona, tendre 10 donde solo el resultado correcto sera 1 y el resto 0)
Y_entrenamiento = to_categorical(Y_entrenamiento)
Y_pruebas = to_categorical(Y_pruebas)

#Convertir a flotante y normalizar para que aprenda mejor la red
X_entrenamiento = X_entrenamiento.astype('float32') / 255
X_pruebas = X_pruebas.astype('float32') / 255

# %%
#Codigo para mostrar imagenes del set, no es necesario ejecutarlo, solo imprime unos numeros :)
import matplotlib.pyplot as plt
filas = 2
columnas = 8
num = filas*columnas
imagenes = X_entrenamiento[0:num]
etiquetas = Y_entrenamiento[0:num]
fig, axes = plt.subplots(filas, columnas, figsize=(1.5*columnas,2*filas))
for i in range(num):
     ax = axes[i//columnas, i%columnas]
     ax.imshow(imagenes[i].reshape(28,28), cmap='gray_r')
     ax.set_title('Label: {}'.format(np.argmax(etiquetas[i])))
plt.tight_layout()
plt.show()

# %%
#Aumento de datos
#Variables para controlar las transformaciones que se haran en el aumento de datos
#utilizando ImageDataGenerator de keras

from tensorflow.keras.preprocessing.image import ImageDataGenerator

rango_rotacion = 30
mov_ancho = 0.25
mov_alto = 0.25
#rango_inclinacion=15 #No uso este de momento pero si quieres puedes probar usandolo!
rango_acercamiento=[0.5,1.5]

datagen = ImageDataGenerator(
    rotation_range = rango_rotacion,
    width_shift_range = mov_ancho,
    height_shift_range = mov_alto,
    zoom_range=rango_acercamiento,
    #shear_range=rango_inclinacion #No uso este de momento pero si quieres puedes probar usandolo!
)

datagen.fit(X_entrenamiento)

# %%
#Codigo para mostrar imagenes del set, no es necesario ejecutarlo, solo imprime como se ven antes y despues de las transformaciones
filas = 4
columnas = 8
num = filas*columnas
print('ANTES:\n')
fig1, axes1 = plt.subplots(filas, columnas, figsize=(1.5*columnas,2*filas))
for i in range(num):
     ax = axes1[i//columnas, i%columnas]
     ax.imshow(X_entrenamiento[i].reshape(28,28), cmap='gray_r')
     ax.set_title('Label: {}'.format(np.argmax(Y_entrenamiento[i])))
plt.tight_layout()
plt.show()
print('DESPUES:\n')
fig2, axes2 = plt.subplots(filas, columnas, figsize=(1.5*columnas,2*filas))
for X, Y in datagen.flow(X_entrenamiento,Y_entrenamiento.reshape(Y_entrenamiento.shape[0], 10),batch_size=num,shuffle=False):
     for i in range(0, num):
          ax = axes2[i//columnas, i%columnas]
          ax.imshow(X[i].reshape(28,28), cmap='gray_r')
          ax.set_title('Label: {}'.format(int(np.argmax(Y[i]))))
     break
plt.tight_layout()
plt.show()
# Out:
# ANTES:
# DESPUES:

# %%
#Modelo!
modelo = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(28, 28, 1)),
    tf.keras.layers.MaxPooling2D(2, 2),

    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),

    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(100, activation='relu'),
    tf.keras.layers.Dense(10, activation="softmax")
])

#Compilación
modelo.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
#Los datos para entrenar saldran del datagen, de manera que sean generados con las transformaciones que indicamos
data_gen_entrenamiento = datagen.flow(X_entrenamiento, Y_entrenamiento, batch_size=32)

# %%
TAMANO_LOTE = 32

print("Entrenando modelo...");
epocas=60
history = modelo.fit(
    data_gen_entrenamiento,
    epochs=epocas,
    batch_size=TAMANO_LOTE,
    validation_data=(X_pruebas, Y_pruebas),
    steps_per_epoch=int(np.ceil(60000 / float(TAMANO_LOTE))),
    validation_steps=int(np.ceil(10000 / float(TAMANO_LOTE)))
)

print("Modelo entrenado!");
# Out:
# Entrenando modelo...
# Epoch 1/60
# 1875/1875 [==============================] - 37s 14ms/step - loss: 1.1859 - accuracy: 0.6026 - val_loss: 0.1667 - val_accuracy: 0.9572
# Epoch 2/60
# 1875/1875 [==============================] - 28s 15ms/step - loss: 0.6840 - accuracy: 0.7810 - val_loss: 0.1388 - val_accuracy: 0.9610
# Epoch 3/60
# 1875/1875 [==============================] - 27s 14ms/step - loss: 0.5751 - accuracy: 0.8141 - val_loss: 0.0912 - val_accuracy: 0.9729
# Epoch 4/60
# 1875/1875 [==============================] - 27s 14ms/step - loss: 0.5132 - accuracy: 0.8343 - val_loss: 0.0824 - val_accuracy: 0.9736
# Epoch 5/60
# 1875/1875 [==============================] - 29s 16ms/step - loss: 0.4789 - accuracy: 0.8453 - val_loss: 0.1049 - val_accuracy: 0.9665
# Epoch 6/60
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.4528 - accuracy: 0.8564 - val_loss: 0.0926 - val_accuracy: 0.9689
# Epoch 7/60
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.4381 - accuracy: 0.8582 - val_loss: 0.0831 - val_accuracy: 0.9720
# Epoch 8/60
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.4183 - accuracy: 0.8645 - val_loss: 0.0806 - val_accuracy: 0.9750
# Epoch 9/60
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.4030 - accuracy: 0.8688 - val_loss: 0.0817 - val_accuracy: 0.9738
# Epoch 10/60
# 1875/1875 [==============================] - 28s 15ms/step - loss: 0.3873 - accuracy: 0.8756 - val_loss: 0.0774 - val_accuracy: 0.9752
# Epoch 11/60
# 1875/1875 [==============================] - 27s 14ms/step - loss: 0.3765 - accuracy: 0.8788 - val_loss: 0.0527 - val_accuracy: 0.9830
# Epoch 12/60
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.3729 - accuracy: 0.8801 - val_loss: 0.0662 - val_accuracy: 0.9783
# Epoch 13/60
# 1875/1875 [==============================] - 27s 14ms/step - loss: 0.3599 - accuracy: 0.8845 - val_loss: 0.0627 - val_accuracy: 0.9798
# Epoch 14/60
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.3590 - accuracy: 0.8841 - val_loss: 0.0531 - val_accuracy: 0.9825
# Epoch 15/60
# 1875/1875 [==============================] - 27s 14ms/step - loss: 0.3538 - accuracy: 0.8844 - val_loss: 0.0688 - val_accuracy: 0.9782
# Epoch 16/60
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.3424 - accuracy: 0.8896 - val_loss: 0.0663 - val_accuracy: 0.9786
# Epoch 17/60
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.3457 - accuracy: 0.8879 - val_loss: 0.0491 - val_accuracy: 0.9848
# Epoch 18/60
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.3354 - accuracy: 0.8930 - val_loss: 0.0577 - val_accuracy: 0.9816
# Epoch 19/60
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.3342 - accuracy: 0.8912 - val_loss: 0.0582 - val_accuracy: 0.9818
# Epoch 20/60
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.3261 - accuracy: 0.8958 - val_loss: 0.0558 - val_accuracy: 0.9823
# Epoch 21/60
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.3303 - accuracy: 0.8935 - val_loss: 0.0577 - val_accuracy: 0.9814
# Epoch 22/60
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.3224 - accuracy: 0.8979 - val_loss: 0.0693 - val_accuracy: 0.9776
# Epoch 23/60
# 1875/1875 [==============================] - 27s 14ms/step - loss: 0.3186 - accuracy: 0.8965 - val_loss: 0.0669 - val_accuracy: 0.9786
# Epoch 24/60
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.3138 - accuracy: 0.8984 - val_loss: 0.0784 - val_accuracy: 0.9749
# Epoch 25/60
# 1875/1875 [==============================] - 28s 15ms/step - loss: 0.3126 - accuracy: 0.8985 - val_loss: 0.0551 - val_accuracy: 0.9818
# Epoch 26/60
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.3149 - accuracy: 0.9001 - val_loss: 0.0854 - val_accuracy: 0.9743
# Epoch 27/60
# 1875/1875 [==============================] - 27s 14ms/step - loss: 0.3059 - accuracy: 0.9003 - val_loss: 0.0707 - val_accuracy: 0.9783
# Epoch 28/60
# 1875/1875 [==============================] - 27s 14ms/step - loss: 0.3094 - accuracy: 0.9020 - val_loss: 0.0825 - val_accuracy: 0.9745
# Epoch 29/60
# 1875/1875 [==============================] - 28s 15ms/step - loss: 0.3029 - accuracy: 0.9017 - val_loss: 0.0723 - val_accuracy: 0.9769
# Epoch 30/60
# 1875/1875 [==============================] - 27s 14ms/step - loss: 0.3056 - accuracy: 0.9030 - val_loss: 0.0569 - val_accuracy: 0.9820
# Epoch 31/60
# 1875/1875 [==============================] - 28s 15ms/step - loss: 0.3029 - accuracy: 0.9021 - val_loss: 0.0601 - val_accuracy: 0.9810
# Epoch 32/60
# 1875/1875 [==============================] - 29s 16ms/step - loss: 0.3001 - accuracy: 0.9031 - val_loss: 0.0685 - val_accuracy: 0.9777
# Epoch 33/60
# 1875/1875 [==============================] - 27s 14ms/step - loss: 0.2937 - accuracy: 0.9061 - val_loss: 0.0583 - val_accuracy: 0.9812
# Epoch 34/60
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.2940 - accuracy: 0.9061 - val_loss: 0.0722 - val_accuracy: 0.9770
# Epoch 35/60
# 1875/1875 [==============================] - 27s 14ms/step - loss: 0.2932 - accuracy: 0.9064 - val_loss: 0.0676 - val_accuracy: 0.9787
# Epoch 36/60
# 1875/1875 [==============================] - 29s 16ms/step - loss: 0.2983 - accuracy: 0.9037 - val_loss: 0.0465 - val_accuracy: 0.9856
# Epoch 37/60
# 1875/1875 [==============================] - 28s 15ms/step - loss: 0.2913 - accuracy: 0.9074 - val_loss: 0.0527 - val_accuracy: 0.9845
# Epoch 38/60
# 1875/1875 [==============================] - 28s 15ms/step - loss: 0.2893 - accuracy: 0.9069 - val_loss: 0.0640 - val_accuracy: 0.9810
# Epoch 39/60
# 1875/1875 [==============================] - 28s 15ms/step - loss: 0.2970 - accuracy: 0.9050 - val_loss: 0.0586 - val_accuracy: 0.9809
# Epoch 40/60
# 1875/1875 [==============================] - 28s 15ms/step - loss: 0.2923 - accuracy: 0.9049 - val_loss: 0.0508 - val_accuracy: 0.9834
# Epoch 41/60
# 1875/1875 [==============================] - 29s 16ms/step - loss: 0.2909 - accuracy: 0.9070 - val_loss: 0.0631 - val_accuracy: 0.9798
# Epoch 42/60
# 1875/1875 [==============================] - 28s 15ms/step - loss: 0.2854 - accuracy: 0.9081 - val_loss: 0.0474 - val_accuracy: 0.9856
# Epoch 43/60
# 1875/1875 [==============================] - 29s 16ms/step - loss: 0.2861 - accuracy: 0.9080 - val_loss: 0.0562 - val_accuracy: 0.9812
# Epoch 44/60
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.2837 - accuracy: 0.9085 - val_loss: 0.0636 - val_accuracy: 0.9801
# Epoch 45/60
# 1875/1875 [==============================] - 29s 15ms/step - loss: 0.2869 - accuracy: 0.9078 - val_loss: 0.0607 - val_accuracy: 0.9813
# Epoch 46/60
# 1875/1875 [==============================] - 28s 15ms/step - loss: 0.2815 - accuracy: 0.9089 - val_loss: 0.0650 - val_accuracy: 0.9818
# Epoch 47/60
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.2834 - accuracy: 0.9097 - val_loss: 0.0586 - val_accuracy: 0.9810
# Epoch 48/60
# 1875/1875 [==============================] - 29s 16ms/step - loss: 0.2759 - accuracy: 0.9117 - val_loss: 0.0561 - val_accuracy: 0.9817
# Epoch 49/60
# 1875/1875 [==============================] - 29s 16ms/step - loss: 0.2817 - accuracy: 0.9097 - val_loss: 0.0590 - val_accuracy: 0.9807
# Epoch 50/60
# 1875/1875 [==============================] - 28s 15ms/step - loss: 0.2865 - accuracy: 0.9076 - val_loss: 0.0627 - val_accuracy: 0.9799
# Epoch 51/60
# 1875/1875 [==============================] - 29s 15ms/step - loss: 0.2809 - accuracy: 0.9101 - val_loss: 0.0482 - val_accuracy: 0.9847
# Epoch 52/60
# 1875/1875 [==============================] - 29s 15ms/step - loss: 0.2773 - accuracy: 0.9111 - val_loss: 0.0727 - val_accuracy: 0.9768
# Epoch 53/60
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.2737 - accuracy: 0.9126 - val_loss: 0.0671 - val_accuracy: 0.9789
# Epoch 54/60
# 1875/1875 [==============================] - 28s 15ms/step - loss: 0.2766 - accuracy: 0.9124 - val_loss: 0.0627 - val_accuracy: 0.9814
# Epoch 55/60
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.2772 - accuracy: 0.9105 - val_loss: 0.0638 - val_accuracy: 0.9814
# Epoch 56/60
# 1875/1875 [==============================] - 28s 15ms/step - loss: 0.2790 - accuracy: 0.9107 - val_loss: 0.0496 - val_accuracy: 0.9852
# Epoch 57/60
# 1875/1875 [==============================] - 28s 15ms/step - loss: 0.2789 - accuracy: 0.9109 - val_loss: 0.0586 - val_accuracy: 0.9829
# Epoch 58/60
# 1875/1875 [==============================] - 28s 15ms/step - loss: 0.2753 - accuracy: 0.9110 - val_loss: 0.0567 - val_accuracy: 0.9828
# Epoch 59/60
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.2742 - accuracy: 0.9118 - val_loss: 0.0571 - val_accuracy: 0.9827
# Epoch 60/60
# 1875/1875 [==============================] - 28s 15ms/step - loss: 0.2760 - accuracy: 0.9101 - val_loss: 0.0477 - val_accuracy: 0.9843
# Modelo entrenado!

# %%
modelo.save('numeros_conv_ad_do.h5')

#Convertirlo a tensorflow.js
# !pip install tensorflowjs

# !mkdir carpeta_salida

# !tensorflowjs_converter --input_format keras numeros_conv_ad_do.h5 carpeta_salida
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Collecting tensorflowjs
#   Downloading tensorflowjs-4.11.0-py3-none-any.whl (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.2/89.2 kB 3.0 MB/s eta 0:00:00
# Requirement already satisfied: flax>=0.7.2 in /usr/local/lib/python3.10/dist-packages (from tensorflowjs) (0.7.2)
# Requirement already satisfied: importlib_resources>=5.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflowjs) (6.0.1)
# Requirement already satisfied: jax>=0.4.13 in /usr/local/lib/python3.10/dist-packages (from tensorflowjs) (0.4.14)
# Requirement already satisfied: jaxlib>=0.4.13 in /usr/local/lib/python3.10/dist-packages (from tensorflowjs) (0.4.14+cuda11.cudnn86)
# Requirement already satisfied: tensorflow<3,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from tensorflowjs) (2.13.0)
# Collecting tensorflow-decision-forests>=1.5.0 (from tensorflowjs)
#   Downloading tensorflow_decision_forests-1.6.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.8/16.8 MB 61.7 MB/s eta 0:00:00
# Requirement already satisfied: six<2,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from tensorflowjs) (1.16.0)
# Requirement already satisfied: tensorflow-hub>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from tensorflowjs) (0.14.0)
# Requirement already satisfied: packaging~=23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflowjs) (23.1)
# Requirement already satisfied: numpy>=1.12 in /usr/local/lib/python3.10/dist-packages (from flax>=0.7.2->tensorflowjs) (1.23.5)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.10/dist-packages (from flax>=0.7.2->tensorflowjs) (1.0.5)
# Requirement already satisfied: optax in /usr/local/lib/python3.10/dist-packages (from flax>=0.7.2->tensorflowjs) (0.1.7)
# Requirement already satisfied: orbax-checkpoint in /usr/local/lib/python3.10/dist-packages (from flax>=0.7.2->tensorflowjs) (0.3.5)
# Requirement already satisfied: tensorstore in /usr/local/lib/python3.10/dist-packages (from flax>=0.7.2->tensorflowjs) (0.1.41)
# Requirement already satisfied: rich>=11.1 in /usr/local/lib/python3.10/dist-packages (from flax>=0.7.2->tensorflowjs) (13.5.2)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.10/dist-packages (from flax>=0.7.2->tensorflowjs) (4.5.0)
# Requirement already satisfied: PyYAML>=5.4.1 in /usr/local/lib/python3.10/dist-packages (from flax>=0.7.2->tensorflowjs) (6.0.1)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from jax>=0.4.13->tensorflowjs) (0.2.0)
# Requirement already satisfied: opt-einsum in /usr/local/lib/python3.10/dist-packages (from jax>=0.4.13->tensorflowjs) (3.3.0)
# Requirement already satisfied: scipy>=1.7 in /usr/local/lib/python3.10/dist-packages (from jax>=0.4.13->tensorflowjs) (1.11.2)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.1.21 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (23.5.26)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (1.57.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (3.9.0)
# Requirement already satisfied: keras<2.14,>=2.13.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (2.13.1)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (16.0.6)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (67.7.2)
# Requirement already satisfied: tensorboard<2.14,>=2.13 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (2.13.0)
# Requirement already satisfied: tensorflow-estimator<2.14,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (2.13.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (2.3.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (1.15.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (0.33.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from tensorflow-decision-forests>=1.5.0->tensorflowjs) (1.5.3)
# Collecting tensorflow<3,>=2.13.0 (from tensorflowjs)
#   Downloading tensorflow-2.14.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (489.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 489.8/489.8 MB 3.6 MB/s eta 0:00:00
# Requirement already satisfied: wheel in /usr/local/lib/python3.10/dist-packages (from tensorflow-decision-forests>=1.5.0->tensorflowjs) (0.41.2)
# Collecting wurlitzer (from tensorflow-decision-forests>=1.5.0->tensorflowjs)
#   Downloading wurlitzer-3.0.3-py3-none-any.whl (7.3 kB)
# Collecting wrapt<1.15,>=1.11.0 (from tensorflow<3,>=2.13.0->tensorflowjs)
#   Downloading wrapt-1.14.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 11.0 MB/s eta 0:00:00
# Collecting tensorboard<2.15,>=2.14 (from tensorflow<3,>=2.13.0->tensorflowjs)
#   Downloading tensorboard-2.14.1-py3-none-any.whl (5.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 107.8 MB/s eta 0:00:00
# Collecting tensorflow-estimator<2.15,>=2.14.0 (from tensorflow<3,>=2.13.0->tensorflowjs)
#   Downloading tensorflow_estimator-2.14.0-py2.py3-none-any.whl (440 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 440.7/440.7 kB 45.0 MB/s eta 0:00:00
# Collecting keras<2.15,>=2.14.0 (from tensorflow<3,>=2.13.0->tensorflowjs)
#   Downloading keras-2.14.0-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 95.3 MB/s eta 0:00:00
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=11.1->flax>=0.7.2->tensorflowjs) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=11.1->flax>=0.7.2->tensorflowjs) (2.16.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow<3,>=2.13.0->tensorflowjs) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow<3,>=2.13.0->tensorflowjs) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow<3,>=2.13.0->tensorflowjs) (3.4.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow<3,>=2.13.0->tensorflowjs) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow<3,>=2.13.0->tensorflowjs) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow<3,>=2.13.0->tensorflowjs) (2.3.7)
# Requirement already satisfied: chex>=0.1.5 in /usr/local/lib/python3.10/dist-packages (from optax->flax>=0.7.2->tensorflowjs) (0.1.7)
# Requirement already satisfied: etils[epath,epy] in /usr/local/lib/python3.10/dist-packages (from orbax-checkpoint->flax>=0.7.2->tensorflowjs) (1.4.1)
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.10/dist-packages (from orbax-checkpoint->flax>=0.7.2->tensorflowjs) (1.5.7)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->tensorflow-decision-forests>=1.5.0->tensorflowjs) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->tensorflow-decision-forests>=1.5.0->tensorflowjs) (2023.3.post1)
# Requirement already satisfied: dm-tree>=0.1.5 in /usr/local/lib/python3.10/dist-packages (from chex>=0.1.5->optax->flax>=0.7.2->tensorflowjs) (0.1.8)
# Requirement already satisfied: toolz>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from chex>=0.1.5->optax->flax>=0.7.2->tensorflowjs) (0.12.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow<3,>=2.13.0->tensorflowjs) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow<3,>=2.13.0->tensorflowjs) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow<3,>=2.13.0->tensorflowjs) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow<3,>=2.13.0->tensorflowjs) (1.3.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=11.1->flax>=0.7.2->tensorflowjs) (0.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow<3,>=2.13.0->tensorflowjs) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow<3,>=2.13.0->tensorflowjs) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow<3,>=2.13.0->tensorflowjs) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow<3,>=2.13.0->tensorflowjs) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.15,>=2.14->tensorflow<3,>=2.13.0->tensorflowjs) (2.1.3)
# Requirement already satisfied: zipp in /usr/local/lib/python3.10/dist-packages (from etils[epath,epy]->orbax-checkpoint->flax>=0.7.2->tensorflowjs) (3.16.2)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow<3,>=2.13.0->tensorflowjs) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow<3,>=2.13.0->tensorflowjs) (3.2.2)
# Installing collected packages: wurlitzer, wrapt, tensorflow-estimator, keras, tensorboard, tensorflow, tensorflow-decision-forests, tensorflowjs
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 1.15.0
#     Uninstalling wrapt-1.15.0:
#       Successfully uninstalled wrapt-1.15.0
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.13.0
#     Uninstalling tensorflow-estimator-2.13.0:
#       Successfully uninstalled tensorflow-estimator-2.13.0
#   Attempting uninstall: keras
#     Found existing installation: keras 2.13.1
#     Uninstalling keras-2.13.1:
#       Successfully uninstalled keras-2.13.1
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.13.0
#     Uninstalling tensorboard-2.13.0:
#       Successfully uninstalled tensorboard-2.13.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.13.0
#     Uninstalling tensorflow-2.13.0:
#       Successfully uninstalled tensorflow-2.13.0
# Successfully installed keras-2.14.0 tensorboard-2.14.1 tensorflow-2.14.0 tensorflow-decision-forests-1.6.0 tensorflow-estimator-2.14.0 tensorflowjs-4.11.0 wrapt-1.14.1 wurlitzer-3.0.3
# 2023-09-29 03:19:46.551070: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-09-29 03:19:46.551124: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-09-29 03:19:46.551171: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-09-29 03:19:47.610970: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
