# %% [markdown]
# <a href="https://colab.research.google.com/github/EduGH15/Algoritmos-de-aprendizaje/blob/main/Red_convolucional_aumento_datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
import numpy as np
from tensorflow.keras.utils import to_categorical

#Cargar los datos de MNIST
#Aqui lo hago de otra manera porque es mas simple para poder usar el modulo de aumento de datos
#de Keras de esta manera
(X_entrenamiento, Y_entrenamiento), (X_pruebas, Y_pruebas) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
#Colocar los datos en la forma correcta que ya hemos visto (1, 28, 28, 1)
X_entrenamiento = X_entrenamiento.reshape(X_entrenamiento.shape[0], 28, 28, 1)
X_pruebas = X_pruebas.reshape(X_pruebas.shape[0], 28, 28, 1)

#Hacer 'one-hot encoding' de los resultados (e.g. en lugar de tener como resultado una sola neurona, tendre 10 donde solo el resultado correcto sera 1 y el resto 0)
Y_entrenamiento = to_categorical(Y_entrenamiento)
Y_pruebas = to_categorical(Y_pruebas)

#Convertir a flotante y normalizar para que aprenda mejor la red
X_entrenamiento = X_entrenamiento.astype('float32') / 255
X_pruebas = X_pruebas.astype('float32') / 255

# %%
#Codigo para mostrar imagenes del set, no es necesario ejecutarlo, solo imprime unos numeros :)
import matplotlib.pyplot as plt
filas = 2
columnas = 8
num = filas*columnas
imagenes = X_entrenamiento[0:num]
etiquetas = Y_entrenamiento[0:num]
fig, axes = plt.subplots(filas, columnas, figsize=(1.5*columnas,2*filas))
for i in range(num):
     ax = axes[i//columnas, i%columnas]
     ax.imshow(imagenes[i].reshape(28,28), cmap='gray_r')
     ax.set_title('Label: {}'.format(np.argmax(etiquetas[i])))
plt.tight_layout()
plt.show()

# %%
#Aumento de datos
#Variables para controlar las transformaciones que se haran en el aumento de datos
#utilizando ImageDataGenerator de keras

from tensorflow.keras.preprocessing.image import ImageDataGenerator

rango_rotacion = 30
mov_ancho = 0.25
mov_alto = 0.25
#rango_inclinacion=15 #No uso este de momento pero si quieres puedes probar usandolo!
rango_acercamiento=[0.5,1.5]

datagen = ImageDataGenerator(
    rotation_range = rango_rotacion,
    width_shift_range = mov_ancho,
    height_shift_range = mov_alto,
    zoom_range=rango_acercamiento,
    #shear_range=rango_inclinacion #No uso este de momento pero si quieres puedes probar usandolo!
)

datagen.fit(X_entrenamiento)

# %%
#Codigo para mostrar imagenes del set, no es necesario ejecutarlo, solo imprime como se ven antes y despues de las transformaciones
filas = 4
columnas = 8
num = filas*columnas
print('ANTES:\n')
fig1, axes1 = plt.subplots(filas, columnas, figsize=(1.5*columnas,2*filas))
for i in range(num):
     ax = axes1[i//columnas, i%columnas]
     ax.imshow(X_entrenamiento[i].reshape(28,28), cmap='gray_r')
     ax.set_title('Label: {}'.format(np.argmax(Y_entrenamiento[i])))
plt.tight_layout()
plt.show()
print('DESPUES:\n')
fig2, axes2 = plt.subplots(filas, columnas, figsize=(1.5*columnas,2*filas))
for X, Y in datagen.flow(X_entrenamiento,Y_entrenamiento.reshape(Y_entrenamiento.shape[0], 10),batch_size=num,shuffle=False):
     for i in range(0, num):
          ax = axes2[i//columnas, i%columnas]
          ax.imshow(X[i].reshape(28,28), cmap='gray_r')
          ax.set_title('Label: {}'.format(int(np.argmax(Y[i]))))
     break
plt.tight_layout()
plt.show()
# Out:
# ANTES:
# DESPUES:

# %%
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir='./logs', histogram_freq=1)

# %%
#Modelo!
modelo = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(28, 28, 1)),
    tf.keras.layers.MaxPooling2D(2, 2),

    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),

    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(100, activation='relu'),
    tf.keras.layers.Dense(10, activation="softmax")
])

#Compilación
modelo.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
#Los datos para entrenar saldran del datagen, de manera que sean generados con las transformaciones que indicamos
data_gen_entrenamiento = datagen.flow(X_entrenamiento, Y_entrenamiento, batch_size=32)

# %%
TAMANO_LOTE = 32

print("Entrenando modelo...");
epocas=60
history = modelo.fit(
    data_gen_entrenamiento,
    epochs=epocas,
    batch_size=TAMANO_LOTE,
    validation_data=(X_pruebas, Y_pruebas),
    steps_per_epoch=int(np.ceil(60000 / float(TAMANO_LOTE))),
    validation_steps=int(np.ceil(10000 / float(TAMANO_LOTE))),
    callbacks=[tensorboard_callback]  # Agrega el callback de TensorBoard aquí

)

print("Modelo entrenado!");
# Out:
# Entrenando modelo...
# Epoch 1/60
# 1875/1875 [==============================] - 38s 14ms/step - loss: 1.1855 - accuracy: 0.6033 - val_loss: 0.1786 - val_accuracy: 0.9503
# Epoch 2/60
# 1875/1875 [==============================] - 27s 15ms/step - loss: 0.7025 - accuracy: 0.7740 - val_loss: 0.1171 - val_accuracy: 0.9646
# Epoch 3/60
# 1875/1875 [==============================] - 27s 14ms/step - loss: 0.5886 - accuracy: 0.8124 - val_loss: 0.0975 - val_accuracy: 0.9691
# Epoch 4/60
# 1875/1875 [==============================] - 27s 14ms/step - loss: 0.5282 - accuracy: 0.8308 - val_loss: 0.0858 - val_accuracy: 0.9720
# Epoch 5/60
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.4907 - accuracy: 0.8432 - val_loss: 0.0918 - val_accuracy: 0.9703
# Epoch 6/60
# 1875/1875 [==============================] - 28s 15ms/step - loss: 0.4575 - accuracy: 0.8535 - val_loss: 0.1009 - val_accuracy: 0.9702
# Epoch 7/60
# 1875/1875 [==============================] - 27s 15ms/step - loss: 0.4406 - accuracy: 0.8582 - val_loss: 0.0800 - val_accuracy: 0.9738
# Epoch 8/60
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.4238 - accuracy: 0.8626 - val_loss: 0.0577 - val_accuracy: 0.9816
# Epoch 9/60
# 1875/1875 [==============================] - 28s 15ms/step - loss: 0.4108 - accuracy: 0.8686 - val_loss: 0.0716 - val_accuracy: 0.9770
# Epoch 10/60
# 1875/1875 [==============================] - 27s 14ms/step - loss: 0.4023 - accuracy: 0.8711 - val_loss: 0.0620 - val_accuracy: 0.9798
# Epoch 11/60
# 1875/1875 [==============================] - 27s 14ms/step - loss: 0.3905 - accuracy: 0.8735 - val_loss: 0.0627 - val_accuracy: 0.9805
# Epoch 12/60
# 1875/1875 [==============================] - 27s 14ms/step - loss: 0.3728 - accuracy: 0.8800 - val_loss: 0.0705 - val_accuracy: 0.9762
# Epoch 13/60
# 1875/1875 [==============================] - 27s 15ms/step - loss: 0.3699 - accuracy: 0.8826 - val_loss: 0.0512 - val_accuracy: 0.9830
# Epoch 14/60
# 1875/1875 [==============================] - 27s 14ms/step - loss: 0.3640 - accuracy: 0.8828 - val_loss: 0.0595 - val_accuracy: 0.9810
# Epoch 15/60
# 1875/1875 [==============================] - 27s 14ms/step - loss: 0.3539 - accuracy: 0.8860 - val_loss: 0.0564 - val_accuracy: 0.9826
# Epoch 16/60
# 1875/1875 [==============================] - 29s 15ms/step - loss: 0.3463 - accuracy: 0.8878 - val_loss: 0.0850 - val_accuracy: 0.9743
# Epoch 17/60
# 1875/1875 [==============================] - 27s 14ms/step - loss: 0.3424 - accuracy: 0.8907 - val_loss: 0.0650 - val_accuracy: 0.9812
# Epoch 18/60
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.3444 - accuracy: 0.8897 - val_loss: 0.0592 - val_accuracy: 0.9806
# Epoch 19/60
# 1875/1875 [==============================] - 29s 15ms/step - loss: 0.3377 - accuracy: 0.8916 - val_loss: 0.0598 - val_accuracy: 0.9814
# Epoch 20/60
# 1875/1875 [==============================] - 27s 15ms/step - loss: 0.3344 - accuracy: 0.8924 - val_loss: 0.0676 - val_accuracy: 0.9791
# Epoch 21/60
# 1875/1875 [==============================] - 27s 14ms/step - loss: 0.3300 - accuracy: 0.8935 - val_loss: 0.0541 - val_accuracy: 0.9822
# Epoch 22/60
# 1875/1875 [==============================] - 27s 14ms/step - loss: 0.3263 - accuracy: 0.8948 - val_loss: 0.0485 - val_accuracy: 0.9834
# Epoch 23/60
# 1875/1875 [==============================] - 27s 15ms/step - loss: 0.3271 - accuracy: 0.8947 - val_loss: 0.0521 - val_accuracy: 0.9832
# Epoch 24/60
# 1875/1875 [==============================] - 28s 15ms/step - loss: 0.3235 - accuracy: 0.8959 - val_loss: 0.0634 - val_accuracy: 0.9794
# Epoch 25/60
# 1875/1875 [==============================] - 29s 15ms/step - loss: 0.3152 - accuracy: 0.8987 - val_loss: 0.0614 - val_accuracy: 0.9812
# Epoch 26/60
# 1875/1875 [==============================] - 27s 15ms/step - loss: 0.3139 - accuracy: 0.8975 - val_loss: 0.0579 - val_accuracy: 0.9824
# Epoch 27/60
# 1875/1875 [==============================] - 27s 14ms/step - loss: 0.3162 - accuracy: 0.8988 - val_loss: 0.0491 - val_accuracy: 0.9847
# Epoch 28/60
# 1875/1875 [==============================] - 27s 14ms/step - loss: 0.3122 - accuracy: 0.8996 - val_loss: 0.0499 - val_accuracy: 0.9844
# Epoch 29/60
# 1875/1875 [==============================] - 28s 15ms/step - loss: 0.3092 - accuracy: 0.9001 - val_loss: 0.0414 - val_accuracy: 0.9860
# Epoch 30/60
# 1875/1875 [==============================] - 27s 15ms/step - loss: 0.3131 - accuracy: 0.9005 - val_loss: 0.0464 - val_accuracy: 0.9861
# Epoch 31/60
# 1875/1875 [==============================] - 27s 15ms/step - loss: 0.3038 - accuracy: 0.9021 - val_loss: 0.0451 - val_accuracy: 0.9861
# Epoch 32/60
# 1875/1875 [==============================] - 28s 15ms/step - loss: 0.3037 - accuracy: 0.9036 - val_loss: 0.0519 - val_accuracy: 0.9837
# Epoch 33/60
# 1875/1875 [==============================] - 27s 15ms/step - loss: 0.3019 - accuracy: 0.9034 - val_loss: 0.0630 - val_accuracy: 0.9793
# Epoch 34/60
# 1875/1875 [==============================] - 27s 14ms/step - loss: 0.3005 - accuracy: 0.9028 - val_loss: 0.0460 - val_accuracy: 0.9853
# Epoch 35/60
# 1875/1875 [==============================] - 27s 15ms/step - loss: 0.3007 - accuracy: 0.9046 - val_loss: 0.0511 - val_accuracy: 0.9847
# Epoch 36/60
# 1875/1875 [==============================] - 28s 15ms/step - loss: 0.2995 - accuracy: 0.9049 - val_loss: 0.0595 - val_accuracy: 0.9835
# Epoch 37/60
# 1875/1875 [==============================] - 27s 15ms/step - loss: 0.2973 - accuracy: 0.9037 - val_loss: 0.0601 - val_accuracy: 0.9812
# Epoch 38/60
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.2984 - accuracy: 0.9036 - val_loss: 0.0445 - val_accuracy: 0.9855
# Epoch 39/60
# 1875/1875 [==============================] - 27s 15ms/step - loss: 0.2915 - accuracy: 0.9057 - val_loss: 0.0524 - val_accuracy: 0.9839
# Epoch 40/60
# 1875/1875 [==============================] - 27s 14ms/step - loss: 0.2934 - accuracy: 0.9053 - val_loss: 0.0542 - val_accuracy: 0.9832
# Epoch 41/60
# 1875/1875 [==============================] - 27s 14ms/step - loss: 0.2902 - accuracy: 0.9072 - val_loss: 0.0435 - val_accuracy: 0.9879
# Epoch 42/60
# 1875/1875 [==============================] - 27s 14ms/step - loss: 0.2911 - accuracy: 0.9058 - val_loss: 0.0552 - val_accuracy: 0.9819
# Epoch 43/60
# 1875/1875 [==============================] - 27s 15ms/step - loss: 0.2907 - accuracy: 0.9058 - val_loss: 0.0459 - val_accuracy: 0.9844
# Epoch 44/60
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.2873 - accuracy: 0.9063 - val_loss: 0.0461 - val_accuracy: 0.9859
# Epoch 45/60
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.2862 - accuracy: 0.9070 - val_loss: 0.0421 - val_accuracy: 0.9868
# Epoch 46/60
# 1875/1875 [==============================] - 27s 14ms/step - loss: 0.2852 - accuracy: 0.9070 - val_loss: 0.0533 - val_accuracy: 0.9840
# Epoch 47/60
# 1875/1875 [==============================] - 28s 15ms/step - loss: 0.2834 - accuracy: 0.9085 - val_loss: 0.0553 - val_accuracy: 0.9842
# Epoch 48/60
# 1875/1875 [==============================] - 27s 14ms/step - loss: 0.2842 - accuracy: 0.9093 - val_loss: 0.0483 - val_accuracy: 0.9853
# Epoch 49/60
# 1875/1875 [==============================] - 27s 14ms/step - loss: 0.2851 - accuracy: 0.9074 - val_loss: 0.0622 - val_accuracy: 0.9808
# Epoch 50/60
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.2804 - accuracy: 0.9103 - val_loss: 0.0548 - val_accuracy: 0.9849
# Epoch 51/60
# 1875/1875 [==============================] - 27s 15ms/step - loss: 0.2831 - accuracy: 0.9097 - val_loss: 0.0554 - val_accuracy: 0.9857
# Epoch 52/60
# 1875/1875 [==============================] - 27s 14ms/step - loss: 0.2802 - accuracy: 0.9097 - val_loss: 0.0403 - val_accuracy: 0.9865
# Epoch 53/60
# 1875/1875 [==============================] - 28s 15ms/step - loss: 0.2818 - accuracy: 0.9099 - val_loss: 0.0536 - val_accuracy: 0.9852
# Epoch 54/60
# 1875/1875 [==============================] - 28s 15ms/step - loss: 0.2786 - accuracy: 0.9087 - val_loss: 0.0553 - val_accuracy: 0.9822
# Epoch 55/60
# 1875/1875 [==============================] - 27s 14ms/step - loss: 0.2770 - accuracy: 0.9109 - val_loss: 0.0530 - val_accuracy: 0.9835
# Epoch 56/60
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.2802 - accuracy: 0.9104 - val_loss: 0.0530 - val_accuracy: 0.9833
# Epoch 57/60
# 1875/1875 [==============================] - 27s 14ms/step - loss: 0.2736 - accuracy: 0.9127 - val_loss: 0.0539 - val_accuracy: 0.9832
# Epoch 58/60
# 1875/1875 [==============================] - 27s 14ms/step - loss: 0.2756 - accuracy: 0.9109 - val_loss: 0.0482 - val_accuracy: 0.9861
# Epoch 59/60
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.2786 - accuracy: 0.9105 - val_loss: 0.0485 - val_accuracy: 0.9853
# Epoch 60/60
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.2749 - accuracy: 0.9105 - val_loss: 0.0475 - val_accuracy: 0.9860
# Modelo entrenado!

# %%
# !tensorboard dev upload \
--logdir "/content/logs" \
--name "Tensorboard" \
--description "Red convolucional + DA + DO" \
--one_shot
# Out:
# 2023-10-01 02:33:08.319683: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
#
# ***** TensorBoard Uploader *****
#
# This will upload your TensorBoard logs to https://tensorboard.dev/ from
# the following directory:
#
# /content/logs
#
# This TensorBoard will be visible to everyone. Do not upload sensitive
# data.
#
# Your use of this service is subject to Google's Terms of Service
# <https://policies.google.com/terms> and Privacy Policy
# <https://policies.google.com/privacy>, and TensorBoard.dev's Terms of Service
# <https://tensorboard.dev/policy/terms/>.
#
# This notice will not be shown again while you are logged into the uploader.
# To log out, run `tensorboard dev auth revoke`.
#
# Continue? (yes/NO) yes
#
# To sign in with the TensorBoard uploader:
#
# 1. On your computer or phone, visit:
#
#    https://www.google.com/device
#
# 2. Sign in with your Google account, then enter:
#
#    FTT-DJN-XMQ
#
#
#
# New experiment created. View your TensorBoard at: https://tensorboard.dev/experiment/zyj3KQ4QQQGXAtDWs9vuag/
#
# [2023-10-01T02:33:40] Started scanning logdir.
# [2023-10-01T02:33:41] Total uploaded: 360 scalars, 480 tensors (344.5 kB), 1 binary objects (80.9 kB)
# [2023-10-01T02:33:41] Done scanning logdir.
#
#
# Done. View your TensorBoard at https://tensorboard.dev/experiment/zyj3KQ4QQQGXAtDWs9vuag/
